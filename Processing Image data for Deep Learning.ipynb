# %% [markdown]
# # Processing image data for Deep Learning.

# %%
# !pip install wget
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# getting the image using web get
from IPython.display import Image
Image(url="https://www.hdwallpapers.in/download/rashi_khanna_in_jil-wide.jpg",width=400,height=400)
# Out:
# <img src="https://www.hdwallpapers.in/download/rashi_khanna_in_jil-wide.jpg" width="400" height="400"/>

# %%
# importing the image module from matplotlib library
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

# %%
img=mpimg.imread("C:\\Users\\Pranav\\Downloads\\rashi_khanna_in_jil-3840x2160.jpg")

# %%
print(img)
# Out:
# [[[227 184 139]
#   [223 179 134]
#   [217 173 128]
#   ...
#   [ 71  81  90]
#   [ 71  81  90]
#   [ 71  81  90]]
#
#  [[228 185 140]
#   [223 179 134]
#   [217 173 128]
#   ...
#   [ 74  84  93]
#   [ 72  82  91]
#   [ 71  81  90]]
#
#  [[230 186 141]
#   [223 179 132]
#   [217 173 126]
#   ...
#   [ 75  85  94]
#   [ 73  83  92]
#   [ 70  80  89]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
# type of image 
type(img)
# Out:
# numpy.ndarray

# %%
# shape of image
print(img.shape)
# Out:
# (2160, 3840, 3)

# %%
img_plot=plt.imshow(img)
plt.show()

# %% [markdown]
# ### Resizing  the image using Pillow library

# %%
from PIL import Image

# %%
img = Image.open("C:\\Users\\Pranav\\Downloads\\rashi_khanna_in_jil-3840x2160.jpg")
img_resize=img.resize((200,200))

# %%
img_resize.save('rashi_khanna_image_resize.jpg')

# %%
# displaying the image from numpy array
img_res=mpimg.imread("C:\\Users\\Pranav\\rashi_khanna_image_resize.jpg")
img_plot=plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %% [markdown]
# ### Converting the RGB image to Grayscale using openCV

# %%
# !pip install opencv-python
# Out:
# ...
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# importing the openCV library
import cv2

# %%
# Use the second argument or (flag value) zero
# that specifies the image is to be read in grayscale mode
img = cv2.imread("C:\\Users\\Pranav\\Downloads\\rashi_khanna_in_jil-3840x2160.jpg", 0)
 
cv2.imshow('Grayscale Image', img)
cv2.waitKey(0)
 
# Window shown waits for any key pressing event
cv2.destroyAllWindows()
